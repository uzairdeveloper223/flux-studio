# %% [markdown]
# # Flux Studio
#
# Welcome to **Flux Studio**! This completely automated notebook will setup FLUX.1 [dev] in ComfyUI with the UltraRealistic Amateur V2 LoRA pre-installed.
#
# ### Instructions:
# 1. Click the **Play** button on the cell below.
# 2. Wait for the installation to finish.
# 3. Once the server starts, it will give you a `loca.lt` link and an **Endpoint IP** password.
# 4. Click the link and paste the IP password to access ComfyUI.

# %%
# !bash <(wget -qO- https://raw.githubusercontent.com/uzairdeveloper223/flux-studio/main/install.sh)
